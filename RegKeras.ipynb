# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanashreeAmbekar/Deep-Learning/blob/main/RegKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Regression with Keras

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Step 1- Data Ingestion

# %%
url1="https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/PowerPlant.csv"
print(url1)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/PowerPlant.csv

# %%
import pandas as pd
df=pd.read_csv(url1)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# ### Target - PE - Power Output in MegaWatts

# %% [markdown]
# AT - Atmospheric Temperature in Degree Celsius...
# V - Vacuum Pressure of Boiler...
# AP - Atmospheric Pressure...
# RH - Relative Humidity in Percentage

# %% [markdown]
# Step 2- Perform Basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 41

# %%
df=df.drop_duplicates(keep="first").reset_index(drop=True)
df
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9522  15.12  48.92  1011.80  72.93  462.59
# 9523  33.41  77.95  1010.30  59.72  432.90
# 9524  15.99  43.34  1014.20  78.66  465.96
# 9525  17.65  59.87  1018.58  94.65  450.93
# 9526  23.68  51.30  1011.86  71.24  451.67
#
# [9527 rows x 5 columns]

# %% [markdown]
# ### Step 3 Seperate X and Y(PE)

# %%
X = df.drop(columns=["PE"])
Y = df[["PE"]]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# ### Step 4- Apply Preprocessing on X

# %%
X.dtypes
# Out:
# AT    float64
# V     float64
# AP    float64
# RH    float64
# dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe=make_pipeline(
    SimpleImputer(strategy="mean"),
    StandardScaler()
).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# ### Step 5 - Apply Train Test split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#             AT         V        AP        RH
# 5695 -0.152905  0.324507  0.089713  1.817999
# 7300 -1.497611 -1.153542  0.323712  0.908830
# 9066 -0.885038 -0.954892  0.293410  0.988245
# 6424  1.398679  1.223949 -0.479290 -1.082031
# 6773 -0.824586 -0.942279  0.796758  1.506499

# %%
ytrain.head()
# Out:
#           PE
# 5695  446.68
# 7300  483.54
# 9066  461.71
# 6424  437.38
# 6773  463.71

# %%
xtest.head()
# Out:
#             AT         V        AP        RH
# 1087  1.827212  1.120683 -0.125767 -1.414069
# 6308 -1.501641 -1.244984  0.044260 -0.467246
# 8021 -1.465370 -1.418408  0.399466 -1.082031
# 9483  0.150695  0.648495  0.731104 -0.002393
# 4459 -0.036032  1.128565 -0.361449  1.586599

# %%
ytest.head()
# Out:
#           PE
# 1087  429.38
# 6308  485.29
# 8021  480.40
# 9483  452.30
# 4459  446.47

# %%
xtrain.shape
# Out:
# (7621, 4)

# %%
xtest.shape
# Out:
# (1906, 4)

# %% [markdown]
# ### Step 6 - Build Neural Network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %%
# Intialize neural network
model = Sequential()

# Add Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add Hidden Layer 1
model.add(Dense(units=8, activation="relu"))

# Add Hidden Layer 2
model.add(Dense(units=4, activation="relu"))

# Output layer
model.add(Dense(units=1, activation="linear"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="mse", optimizer="adam", metrics=["mae"])

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 205823.0469 - mae: 453.3681 - val_loss: 201432.3594 - val_mae: 448.5311
# Epoch 2/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 199134.2344 - mae: 445.9985 - val_loss: 185398.3906 - val_mae: 430.4442
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 178555.0469 - mae: 422.3332 - val_loss: 151275.5938 - val_mae: 388.3567
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 140660.4688 - mae: 373.6711 - val_loss: 106114.7891 - val_mae: 321.2578
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95356.4453 - mae: 301.7040 - val_loss: 65599.3047 - val_mae: 239.8681
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58478.0195 - mae: 222.5037 - val_loss: 39863.0781 - val_mae: 176.4976
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35875.0586 - mae: 165.7234 - val_loss: 25732.2363 - val_mae: 137.4169
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23667.1484 - mae: 131.3277 - val_loss: 17809.7832 - val_mae: 113.3522
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 16615.5566 - mae: 108.7519 - val_loss: 13403.7578 - val_mae: 98.4771
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12966.3184 - mae: 96.5362 - val_loss: 10550.5020 - val_mae: 87.3265
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9938.8633 - mae: 84.2846 - val_loss: 8240.7930 - val_mae: 76.7496
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7652.7847 - mae: 73.4285 - val_loss: 6247.6450 - val_mae: 66.2009
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5726.6265 - mae: 63.0439 - val_loss: 4528.9507 - val_mae: 55.4275
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4067.9438 - mae: 52.4295 - val_loss: 3164.5312 - val_mae: 45.5420
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2831.1130 - mae: 43.2491 - val_loss: 2168.0002 - val_mae: 37.3021
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1940.7676 - mae: 35.3105 - val_loss: 1491.7524 - val_mae: 30.4764
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1394.3936 - mae: 29.6235 - val_loss: 1036.1189 - val_mae: 25.1217
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 994.5176 - mae: 24.5299 - val_loss: 744.6518 - val_mae: 20.9178
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 684.5061 - mae: 20.3462 - val_loss: 556.6964 - val_mae: 17.8603
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 548.3467 - mae: 17.8646 - val_loss: 437.3388 - val_mae: 15.7415
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 429.3820 - mae: 15.6743 - val_loss: 358.9185 - val_mae: 14.2392
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 368.2196 - mae: 14.4539 - val_loss: 308.2161 - val_mae: 13.0137
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 305.9525 - mae: 13.1480 - val_loss: 268.6760 - val_mae: 12.1484
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 269.8894 - mae: 12.3155 - val_loss: 238.4429 - val_mae: 11.4712
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 247.4011 - mae: 11.6296 - val_loss: 214.6791 - val_mae: 10.7846
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 208.8947 - mae: 10.7837 - val_loss: 194.4766 - val_mae: 10.1969
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 183.9460 - mae: 10.1766 - val_loss: 177.2542 - val_mae: 9.7910
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 183.1285 - mae: 9.9868 - val_loss: 160.5377 - val_mae: 9.1952
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 162.4098 - mae: 9.3702 - val_loss: 145.5592 - val_mae: 8.6981
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 145.5101 - mae: 8.7814 - val_loss: 133.7146 - val_mae: 8.2795
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128.6937 - mae: 8.2319 - val_loss: 120.8315 - val_mae: 7.7614
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 121.1705 - mae: 7.8974 - val_loss: 109.9215 - val_mae: 7.4110
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 105.7186 - mae: 7.4217 - val_loss: 100.0910 - val_mae: 7.0751
# Epoch 34/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.5406 - mae: 7.1161 - val_loss: 91.5797 - val_mae: 6.7137
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 91.2430 - mae: 6.7684 - val_loss: 83.4937 - val_mae: 6.4036
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 81.2708 - mae: 6.3890 - val_loss: 76.5514 - val_mae: 6.1447
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 78.3738 - mae: 6.2742 - val_loss: 70.2501 - val_mae: 5.8655
# Epoch 38/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 72.3606 - mae: 5.9500 - val_loss: 64.8345 - val_mae: 5.6794
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 66.6219 - mae: 5.8262 - val_loss: 59.7507 - val_mae: 5.4613
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 59.7683 - mae: 5.5987 - val_loss: 56.2254 - val_mae: 5.3546
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 58.0276 - mae: 5.4592 - val_loss: 51.8594 - val_mae: 5.1770
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.1622 - mae: 5.1603 - val_loss: 48.3865 - val_mae: 5.0396
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 49.2504 - mae: 5.0997 - val_loss: 45.6405 - val_mae: 4.9277
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 47.2581 - mae: 5.0313 - val_loss: 42.3626 - val_mae: 4.7726
# Epoch 45/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 44.3586 - mae: 4.9090 - val_loss: 39.8991 - val_mae: 4.6767
# Epoch 46/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 39.7392 - mae: 4.6996 - val_loss: 38.0590 - val_mae: 4.6187
# Epoch 47/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42.8710 - mae: 4.7378 - val_loss: 35.6184 - val_mae: 4.4796
# Epoch 48/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35.7619 - mae: 4.4523 - val_loss: 34.5087 - val_mae: 4.4449
# Epoch 49/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.3822 - mae: 4.5403 - val_loss: 32.4702 - val_mae: 4.3371
# Epoch 50/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.1800 - mae: 4.4511 - val_loss: 31.0197 - val_mae: 4.2853
# Epoch 51/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.9187 - mae: 4.3116 - val_loss: 29.3914 - val_mae: 4.1806
# Epoch 52/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.2147 - mae: 4.2160 - val_loss: 28.1749 - val_mae: 4.1056
# Epoch 53/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.2107 - mae: 4.1314 - val_loss: 27.4617 - val_mae: 4.0946
# Epoch 54/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.5766 - mae: 4.0800 - val_loss: 26.1017 - val_mae: 3.9571
# Epoch 55/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.7607 - mae: 4.0362 - val_loss: 25.3663 - val_mae: 3.9375
# Epoch 56/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.9532 - mae: 3.9983 - val_loss: 24.1409 - val_mae: 3.8551
# Epoch 57/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.2305 - mae: 3.9628 - val_loss: 23.2913 - val_mae: 3.7915
# Epoch 58/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.7533 - mae: 3.8088 - val_loss: 23.4754 - val_mae: 3.8401
# Epoch 59/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 22.8843 - mae: 3.7831 - val_loss: 21.9044 - val_mae: 3.6898
# Epoch 60/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 22.8803 - mae: 3.7312 - val_loss: 21.1828 - val_mae: 3.6119
# Epoch 61/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.1903 - mae: 3.6838 - val_loss: 21.5936 - val_mae: 3.6792
# Epoch 62/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 21.1638 - mae: 3.6458 - val_loss: 20.3565 - val_mae: 3.5574
# Epoch 63/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.2675 - mae: 3.5984 - val_loss: 20.3106 - val_mae: 3.5516
# Epoch 64/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4917 - mae: 3.6225 - val_loss: 20.0631 - val_mae: 3.4918
# Epoch 65/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2654 - mae: 3.5127 - val_loss: 20.0687 - val_mae: 3.5020
# Epoch 66/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.2344 - mae: 3.4945 - val_loss: 19.4512 - val_mae: 3.4586
# Epoch 67/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.5170 - mae: 3.4749 - val_loss: 19.2275 - val_mae: 3.4312
# Epoch 68/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.3185 - mae: 3.4941 - val_loss: 18.8653 - val_mae: 3.3913
# Epoch 69/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.3680 - mae: 3.4346 - val_loss: 19.0823 - val_mae: 3.4106
# Epoch 70/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.6904 - mae: 3.4403 - val_loss: 19.4500 - val_mae: 3.4571
# Epoch 71/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 19.9976 - mae: 3.4811 - val_loss: 19.2620 - val_mae: 3.4075
# Epoch 72/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.9085 - mae: 3.4310 - val_loss: 18.9476 - val_mae: 3.3836
# Epoch 73/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 19.6237 - mae: 3.4837 - val_loss: 19.1363 - val_mae: 3.4368
# Epoch 74/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 19.0365 - mae: 3.5158 - val_loss: 18.6636 - val_mae: 3.3600
# Epoch 75/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.5333 - mae: 3.3831 - val_loss: 18.9630 - val_mae: 3.4209
# Epoch 76/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.6524 - mae: 3.4417 - val_loss: 19.2057 - val_mae: 3.4243
# Epoch 77/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9298 - mae: 3.4011 - val_loss: 19.0406 - val_mae: 3.4067
# Epoch 78/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.7705 - mae: 3.4318 - val_loss: 18.9423 - val_mae: 3.4005
# Epoch 79/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.8482 - mae: 3.4643 - val_loss: 18.7048 - val_mae: 3.3883
# Epoch 80/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.1206 - mae: 3.3810 - val_loss: 18.7186 - val_mae: 3.3921
# Epoch 81/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.7161 - mae: 3.4184 - val_loss: 18.8492 - val_mae: 3.4099
# Epoch 82/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.6025 - mae: 3.4361 - val_loss: 18.8081 - val_mae: 3.3990
# Epoch 83/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.1962 - mae: 3.4046 - val_loss: 18.7948 - val_mae: 3.3728
# Epoch 84/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.2630 - mae: 3.5037 - val_loss: 19.0124 - val_mae: 3.4153
# Epoch 85/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.5471 - mae: 3.4395 - val_loss: 18.9576 - val_mae: 3.3903
# Epoch 86/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9770 - mae: 3.3674 - val_loss: 18.6768 - val_mae: 3.3710
# Epoch 87/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.1694 - mae: 3.4243 - val_loss: 18.7602 - val_mae: 3.4010
# Epoch 88/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.6011 - mae: 3.3477 - val_loss: 18.6379 - val_mae: 3.3835
# Epoch 89/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.3571 - mae: 3.4641 - val_loss: 18.7826 - val_mae: 3.3999
# Epoch 90/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.5746 - mae: 3.3982 - val_loss: 19.0599 - val_mae: 3.4314
# Epoch 91/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.2463 - mae: 3.3801 - val_loss: 18.9541 - val_mae: 3.4088
# Epoch 92/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.9431 - mae: 3.4016 - val_loss: 18.6553 - val_mae: 3.3912
# Epoch 93/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.8069 - mae: 3.4120 - val_loss: 18.9549 - val_mae: 3.4234
# Epoch 94/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7151 - mae: 3.4107 - val_loss: 18.8416 - val_mae: 3.4152
# Epoch 95/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.1893 - mae: 3.4137 - val_loss: 18.7999 - val_mae: 3.3748
# Epoch 96/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 20.8984 - mae: 3.5318 - val_loss: 18.8878 - val_mae: 3.3816
# Epoch 97/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.4544 - mae: 3.3915 - val_loss: 18.9772 - val_mae: 3.3800
# Epoch 98/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 19.3579 - mae: 3.4401 - val_loss: 18.6084 - val_mae: 3.3733
# Epoch 99/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.4293 - mae: 3.4389 - val_loss: 19.6727 - val_mae: 3.4834
# Epoch 100/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.6160 - mae: 3.3879 - val_loss: 19.2344 - val_mae: 3.4523

# %% [markdown]
# ### Plot the learning curve

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.plot(hist.history["loss"], label="Train Loss")
plt.plot(hist.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.8413 - mae: 3.4843
# [19.079214096069336, 3.4796195030212402]

# %%
model.evaluate(xtest, ytest)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1464 - mae: 3.4445
# [18.937055587768555, 3.485922336578369]

# %%
ypred_train = model.predict(xtrain)
ypred_test = model.predict(xtest)
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
ypred_train[0:5]
# Out:
# array([[450.11432],
#        [478.12985],
#        [467.74817],
#        [433.54984],
#        [465.44937]], dtype=float32)

# %%
ytrain.head()
# Out:
#           PE
# 5695  446.68
# 7300  483.54
# 9066  461.71
# 6424  437.38
# 6773  463.71

# %%
ypred_test[0:5]
# Out:
# array([[429.8097 ],
#        [480.84818],
#        [481.1279 ],
#        [449.44724],
#        [445.75916]], dtype=float32)

# %%
ytest.head()
# Out:
#           PE
# 1087  429.38
# 6308  485.29
# 8021  480.40
# 9483  452.30
# 4459  446.47

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytrain,ypred_train)
# Out:
# 0.9336202144622803

# %%
r2_score(ytest, ypred_test)
# Out:
# 0.9372507929801941

# %% [markdown]
# ### From above i conclude the model is good and can be used for out of sample prediction

# %% [markdown]
# ### Step 8 - Out Of Sample prediction

# %%
url2= "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/test_PowerPlant.csv"
print(url2)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/test_PowerPlant.csv

# %%
xnew = pd.read_csv(url2)

# %%
xnew
# Out:
#        AT      V       AP     RH
# 0   22.49  58.82  1009.73  85.19
# 1   28.88  54.89  1007.16  46.60
# 2   27.89  73.21  1001.32  85.88
# 3   25.69  62.26  1011.38  74.08
# 4   12.16  40.81  1025.79  70.97
# ..    ...    ...      ...    ...
# 95  26.35  69.48  1008.45  70.47
# 96  11.78  39.96  1011.37  82.95
# 97   5.62  41.38  1020.91  86.21
# 98  24.96  74.99  1008.25  80.52
# 99   9.48  40.80  1023.82  78.98
#
# [100 rows x 4 columns]

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
xnew_pre=num_pipe.transform(xnew)
xnew_pre
# Out:
#           AT         V        AP        RH
# 0   0.380410  0.356827 -0.590397  0.811615
# 1   1.238819  0.047028 -1.023041 -1.830315
# 2   1.105826  1.491180 -2.006171  0.858853
# 3   0.810286  0.628000 -0.312629  0.051007
# 4  -1.007284 -1.062888  2.113209 -0.161908
# ..       ...       ...       ...       ...
# 95  0.898948  1.197147 -0.805877 -0.196139
# 96 -1.058331 -1.129893 -0.314313  0.658261
# 97 -1.885843 -1.017956  1.291690  0.881445
# 98  0.712221  1.631496 -0.839546  0.491899
# 99 -1.367305 -1.063677  1.781571  0.386469
#
# [100 rows x 4 columns]

# %%
preds = model.predict(xnew_pre)
preds[0:5]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[445.07187],
#        [440.92105],
#        [430.8569 ],
#        [440.68686],
#        [470.4174 ]], dtype=float32)

# %%
xnew["PE_pred"] = preds.round(2)

# %%
xnew
# Out:
#        AT      V       AP     RH     PE_pred
# 0   22.49  58.82  1009.73  85.19  445.070007
# 1   28.88  54.89  1007.16  46.60  440.920013
# 2   27.89  73.21  1001.32  85.88  430.859985
# 3   25.69  62.26  1011.38  74.08  440.690002
# 4   12.16  40.81  1025.79  70.97  470.420013
# ..    ...    ...      ...    ...         ...
# 95  26.35  69.48  1008.45  70.47  437.549988
# 96  11.78  39.96  1011.37  82.95  471.760010
# 97   5.62  41.38  1020.91  86.21  483.799988
# 98  24.96  74.99  1008.25  80.52  436.730011
# 99   9.48  40.80  1023.82  78.98  475.700012
#
# [100 rows x 5 columns]

# %%
xnew.to_csv("Results.csv", index=False)

# %% [markdown]
# ### Save the model object

# %%
model.save("PowerModel.keras")

# %% [markdown]
# ### Load the model

# %%
from keras.models import load_model

# %%
m = load_model("/content/PowerModel.keras")
m.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)
